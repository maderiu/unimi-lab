# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import PromptTemplate 
from langchain_core.runnables import RunnableMap, RunnableLambda, RunnablePassthrough
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from dotenv import load_dotenv
import pandas as pd 

load_dotenv()
# Out:
# True

# %% [markdown]
# 1. Load the Dataset and inspect it

# %%
df = pd.read_csv('dataset/serie_a_forwards.csv')
df.head()
# Out:
#             full_name country_code role  season       team  mins_played  \
# 0  Zlatan Ibrahimovic          SWE   FW    2021      Milan         1008
# 1  Fabio Quagliarella          ITA   FW    2021  Sampdoria         1658
# 2   Cristiano Ronaldo          PRT   FW    2021   Juventus           31
# 3        Goran Pandev          MKD   FW    2021      Genoa          835
# 4       Stefano Okaka          ITA   FW    2021    Udinese           20
#
#          xG  goals        xA  assists        xT  xT_from_passes  \
# 0  6.252449    8.0  2.012261      3.0  0.794123        0.635827
# 1  4.259178    4.0  1.837090      3.0  0.630270        0.585217
# 2  0.236411    NaN  0.028131      NaN -0.018240       -0.017597
# 3  0.464921    NaN  1.186817      1.0  0.627832        0.349661
# 4  0.033823    NaN  0.001525      1.0  0.016907        0.002524
#
#    xT_from_carries  won_dribblings  attempted_dribblings  \
# 0         0.158296             5.0                   9.0
# 1         0.045052            11.0                  23.0
# 2        -0.000644             1.0                   1.0
# 3         0.278171            10.0                  22.0
# 4         0.014382             NaN                   NaN
#
#    won_dribblings_ratio  offensive_aero
# 0                0.5556         68.9437
# 1                0.4783         38.1917
# 2                1.0000             NaN
# 3                0.4545         40.5377
# 4                   NaN         54.5864

# %%
df.columns
# Out:
# Index(['full_name', 'country_code', 'role', 'season', 'team', 'mins_played',
#        'xG', 'goals', 'xA', 'assists', 'xT', 'xT_from_passes',
#        'xT_from_carries', 'won_dribblings', 'attempted_dribblings',
#        'won_dribblings_ratio', 'offensive_aero'],
#       dtype='object')

# %% [markdown]
# 2. Data preprocessing. Here you can add what you think might be useful to have a better seasonal analysis. Examples:
#  - over / under performance indicators
#  - normalizations
#  - percentiles
#  - rankings

# %%
#calculate percentile of stats vs players in the same season
cols_to_pct = ['xG', 'goals', 'xA', 'assists', 'xT', 'xT_from_passes',
       'xT_from_carries', 'won_dribblings', 'attempted_dribblings',
       'won_dribblings_ratio', 'offensive_aero']

for stat in cols_to_pct:
    df[stat + '_percentile'] = df.groupby('season')[stat].rank(pct=True)


float_cols = df.select_dtypes(include=['float']).columns
df[float_cols] = df[float_cols].round(2)

# %%
(   df
    .query('season == 2023')
    .sort_values('xG', ascending=False)
    [['full_name', 'season','xG', 'xG_percentile', 'goals', 'goals_percentile']]
    .head(10)
)
# Out:
#                  full_name  season     xG  xG_percentile  goals  \
# 496       Lautaro Martínez    2023  15.59           1.00   23.0
# 545         Dusan Vlahovic    2023  15.21           0.99   15.0
# 495          Marcus Thuram    2023  12.50           0.99   10.0
# 564         Olivier Giroud    2023  11.15           0.98   12.0
# 578          Romelu Lukaku    2023  10.32           0.98   10.0
# 575  Khvicha Kvaratskhelia    2023  10.26           0.97   10.0
# 489         Victor Osimhen    2023  10.07           0.96   11.0
# 532          Ciro Immobile    2023   9.62           0.96    6.0
# 570           Paulo Dybala    2023   9.40           0.95   12.0
# 574        Nikola Krstovic    2023   9.24           0.94    5.0
#
#      goals_percentile
# 496              1.00
# 545              0.99
# 495              0.92
# 564              0.98
# 578              0.92
# 575              0.92
# 489              0.96
# 532              0.78
# 570              0.98
# 574              0.72

# %% [markdown]
# 3. Write a prompt template to extract the informations you need, so player full name and season indication.
#
# Your goal here is to have the model generating a structured output, from which you can parse the relevant information (dict, list, comma separated string...)
#
# Optional: To have a more flexible app that could also compare players, think of way to extract multiple players at once

# %%
PLAYER_INFO_TEMPLATE = '''
You are a words extractor from a given input. 
Your job is to extract words following instructions and providing them in a specific format.
Given a user question you must extract:
- Player full names
- Seasons

Provide the output as a list of dictionaries, where each pair player-season is a dict.
Follow this structure: 
[
        {{'full_name': '<player_name_1>' (str), 'season': <season_value_1> (int)}},
        ...{{'full_name': '<player_name_N>' (str), 'season': <season_value_N> (int)}}]

The season indication is a 4 digits number, indicating the year of the first matchday (e.g. 2020, 2021, 2022 and so on).
Note that the current season is 2023.

Example: Paulo Dybala seasonal performance in 2022. 
Output: [{{'full_name': 'Paulo Dybala', 'season': 2022}}]

Here is the input to process: 
{input}
'''

player_info_template = PromptTemplate(
        template=PLAYER_INFO_TEMPLATE, 
        input_variables=['input']
        )


llm = ChatOpenAI(model='gpt-3.5-turbo', timeout=4, max_retries=3, temperature=0)
info_chain = player_info_template | llm

# %% [markdown]
# 4. Test the extraction step! Look at the output and then find a way to parse it into a python data structure

# %%
input = 'Compare the seasons of Paulo Dybala in 2022 and Dusan Vlahovic in 2021'
result = info_chain.invoke({'input':input})
result.content
res = eval(result.content)

# %%
res = eval(result.content)
res
# Out:
# [{'full_name': 'Paulo Dybala', 'season': 2022},
#  {'full_name': 'Dusan Vlahovic', 'season': 2021}]

# %%
print(res, type(res), type(res[0]))
# Out:
# [{'full_name': 'Paulo Dybala', 'season': 2022}, {'full_name': 'Dusan Vlahovic', 'season': 2021}] <class 'list'> <class 'dict'>

# %% [markdown]
# 5. Filter the player you want to analyze (select the correct season!) from the dataframe

# %%
players_to_filter = pd.DataFrame(res)
players_to_filter
# Out:
#         full_name  season
# 0    Paulo Dybala    2022
# 1  Dusan Vlahovic    2021

# %%
filtered_df = pd.merge(df, players_to_filter, on=['full_name', 'season'], how='inner')

# %%
filtered_df
# Out:
#         full_name country_code role  season        team  mins_played     xG  \
# 0  Dusan Vlahovic          SRB   FW    2021  Fiorentina         1861  12.05
# 1  Dusan Vlahovic          SRB   FW    2021    Juventus         1077   5.67
# 2    Paulo Dybala          ARG   FW    2022        Roma         1751   9.69
#
#    goals    xA  assists  ...  goals_percentile  xA_percentile  \
# 0   17.0  2.75      2.0  ...              0.97           0.82
# 1    7.0  0.39      1.0  ...              0.68           0.39
# 2   12.0  4.08      6.0  ...              0.91           0.92
#
#    assists_percentile  xT_percentile  xT_from_passes_percentile  \
# 0                0.44           0.60                       0.64
# 1                0.16           0.45                       0.13
# 2                0.91           0.93                       0.92
#
#    xT_from_carries_percentile  won_dribblings_percentile  \
# 0                        0.60                       0.63
# 1                        0.51                       0.43
# 2                        0.92                       0.78
#
#    attempted_dribblings_percentile  won_dribblings_ratio_percentile  \
# 0                             0.62                             0.60
# 1                             0.54                             0.17
# 2                             0.76                             0.56
#
#    offensive_aero_percentile
# 0                       0.95
# 1                       0.90
# 2                       0.06
#
# [3 rows x 28 columns]

# %% [markdown]
# 6. Check your filtered df

# %%
filtered_df
# Out:
#         full_name country_code role  season        team  mins_played     xG  \
# 0  Dusan Vlahovic          SRB   FW    2021  Fiorentina         1861  12.05
# 1  Dusan Vlahovic          SRB   FW    2021    Juventus         1077   5.67
# 2    Paulo Dybala          ARG   FW    2022        Roma         1751   9.69
#
#    goals    xA  assists  ...  goals_percentile  xA_percentile  \
# 0   17.0  2.75      2.0  ...              0.97           0.82
# 1    7.0  0.39      1.0  ...              0.68           0.39
# 2   12.0  4.08      6.0  ...              0.91           0.92
#
#    assists_percentile  xT_percentile  xT_from_passes_percentile  \
# 0                0.44           0.60                       0.64
# 1                0.16           0.45                       0.13
# 2                0.91           0.93                       0.92
#
#    xT_from_carries_percentile  won_dribblings_percentile  \
# 0                        0.60                       0.63
# 1                        0.51                       0.43
# 2                        0.92                       0.78
#
#    attempted_dribblings_percentile  won_dribblings_ratio_percentile  \
# 0                             0.62                             0.60
# 1                             0.54                             0.17
# 2                             0.76                             0.56
#
#    offensive_aero_percentile
# 0                       0.95
# 1                       0.90
# 2                       0.06
#
# [3 rows x 28 columns]

# %% [markdown]
# 7. Transform your filtered dataframe into a list of dict (Hint: .to_dict(orient='records'))

# %%
players_data = filtered_df.to_dict(orient='records')

# %%
players_data
# Out:
# [{'full_name': 'Dusan Vlahovic',
#   'country_code': 'SRB',
#   'role': 'FW',
#   'season': 2021,
#   'team': 'Fiorentina',
#   'mins_played': 1861,
#   'xG': 12.05,
#   'goals': 17.0,
#   'xA': 2.75,
#   'assists': 2.0,
#   'xT': 0.66,
#   'xT_from_passes': 0.29,
#   'xT_from_carries': 0.37,
#   'won_dribblings': 20.0,
#   'attempted_dribblings': 37.0,
#   'won_dribblings_ratio': 0.54,
#   'offensive_aero': 68.74,
#   'xG_percentile': 0.93,
#   'goals_percentile': 0.97,
#   'xA_percentile': 0.82,
#   'assists_percentile': 0.44,
#   'xT_percentile': 0.6,
#   'xT_from_passes_percentile': 0.64,
#   'xT_from_carries_percentile': 0.6,
#   'won_dribblings_percentile': 0.63,
#   'attempted_dribblings_percentile': 0.62,
#   'won_dribblings_ratio_percentile': 0.6,
#   'offensive_aero_percentile': 0.95},
#  {'full_name': 'Dusan Vlahovic',
#   'country_code': 'SRB',
#   'role': 'FW',
#   'season': 2021,
#   'team': 'Juventus',
#   'mins_played': 1077,
#   'xG': 5.67,
#   'goals': 7.0,
#   'xA': 0.39,
#   'assists': 1.0,
#   'xT': 0.17,
#   'xT_from_passes': -0.07,
#   'xT_from_carries': 0.25,
#   'won_dribblings': 11.0,
#   'attempted_dribblings': 27.0,
#   'won_dribblings_ratio': 0.41,
#   'offensive_aero': 63.46,
#   'xG_percentile': 0.74,
#   'goals_percentile': 0.68,
#   'xA_percentile': 0.39,
#   'assists_percentile': 0.16,
#   'xT_percentile': 0.45,
#   'xT_from_passes_percentile': 0.13,
#   'xT_from_carries_percentile': 0.51,
#   'won_dribblings_percentile': 0.43,
#   'attempted_dribblings_percentile': 0.54,
#   'won_dribblings_ratio_percentile': 0.17,
#   'offensive_aero_percentile': 0.9},
#  {'full_name': 'Paulo Dybala',
#   'country_code': 'ARG',
#   'role': 'FW',
#   'season': 2022,
#   'team': 'Roma',
#   'mins_played': 1751,
#   'xG': 9.69,
#   'goals': 12.0,
#   'xA': 4.08,
#   'assists': 6.0,
#   'xT': 2.27,
#   'xT_from_passes': 1.16,
#   'xT_from_carries': 1.11,
#   'won_dribblings': 27.0,
#   'attempted_dribblings': 54.0,
#   'won_dribblings_ratio': 0.5,
#   'offensive_aero': 28.8,
#   'xG_percentile': 0.91,
#   'goals_percentile': 0.91,
#   'xA_percentile': 0.92,
#   'assists_percentile': 0.91,
#   'xT_percentile': 0.93,
#   'xT_from_passes_percentile': 0.92,
#   'xT_from_carries_percentile': 0.92,
#   'won_dribblings_percentile': 0.78,
#   'attempted_dribblings_percentile': 0.76,
#   'won_dribblings_ratio_percentile': 0.56,
#   'offensive_aero_percentile': 0.06}]

# %% [markdown]
# 8. Write a prompt template to generate the final report given:
# - user input
# - extracted data
# - metrics description (you can load them from  the script utils/descriptions.py)
#
# Use the prompt techniques described into the lecture if you think they might fit. There is no right or wrong solution here.
# Prompt engineering is a trial and error process, try different things and be creative!

# %%
from utils.descriptions import Descriptions
OUTPUT_TEMPLATE = '''
You are a soccer data analyst. You are provided with a user input and useful advanced metrics to answer the question.
If multiple players are provided, try to perform a comparison between them.

User input: {input}
Data: {data}

Use these definitions to better understand the metrics you are provided: 
{stat_description}

If a player has played in multiple teams in the same season, try compare the two situations when possible. 
Make your analysis as a report. 
Divide your analysis in three parts:

1. Creation: talk about assists and xA, xT and dribblings skill when notable
2. Finishing: talk about goals and xG and how they compare (over / under performance?) and about areial dominance (use AERO elo value!)
3. Overall conclusion, tell who is better overall in case of comparisons 

Make it a coherent text not a bullet point list. Put a title, and paragraph names well formatted.
'''


output_template = PromptTemplate(
        template=OUTPUT_TEMPLATE, 
        input_variables = ['input', 'data'], 
        partial_variables={'stat_description': Descriptions.stats}
        )

llm = ChatOpenAI(model='gpt-3.5-turbo', timeout=30, max_retries=3, temperature=0)

output_chain = output_template | llm

# %% [markdown]
# 9. Invoke the chain and see results!

# %%
report = output_chain.invoke(
    {
        'input': input, 
        'data': players_data,
        }
    )

# %%
from pprint import pprint
pprint(report.content)
# Out:
# ('**Analysis of Paulo Dybala in 2022 vs Dusan Vlahovic in 2021**\n'
#  '\n'
#  '**Creation:**\n'
#  'In terms of creation, Paulo Dybala had a standout season in 2022 with Roma. '
#  'He recorded 6 assists and an impressive xA of 4.08, showcasing his ability '
#  'to create goal-scoring opportunities for his teammates. On the other hand, '
#  'Dusan Vlahovic had a solid season in 2021 with Fiorentina and Juventus, '
#  "recording a total of 3 assists and an xA of 3.14. Dybala's higher xA "
#  'indicates that he was more effective in creating high-quality chances for '
#  'his team compared to Vlahovic.\n'
#  '\n'
#  'When it comes to expected threat (xT), Dybala also outperformed Vlahovic. '
#  "Dybala's xT of 2.27 was significantly higher than Vlahovic's combined xT of "
#  '0.34 from both teams he played for in 2021. This suggests that Dybala was '
#  "more influential in increasing his team's scoring probability through his "
#  'actions on the field.\n'
#  '\n'
#  'In terms of dribbling, Dybala had a higher success rate in winning dribbles '
#  "with a ratio of 0.5 compared to Vlahovic's ratio of 0.45. Dybala also "
#  'attempted more dribbles (54) compared to Vlahovic (37), showcasing his '
#  'confidence and skill in taking on defenders.\n'
#  '\n'
#  '**Finishing:**\n'
#  'When it comes to finishing, both Dybala and Vlahovic had impressive '
#  'goal-scoring seasons. Dybala scored 12 goals with an xG of 9.69, indicating '
#  'that he slightly overperformed in front of goal. Vlahovic, on the other '
#  'hand, scored a total of 24 goals (17 for Fiorentina and 7 for Juventus) with '
#  'an xG of 17.72, suggesting that he also overperformed in terms of '
#  'goal-scoring.\n'
#  '\n'
#  'In terms of aerial dominance, Dybala had an offensive AERO rating of 28.8, '
#  'indicating a moderate probability of winning offensive aerial duels. '
#  'Vlahovic, on the other hand, had a higher offensive AERO rating of 66.6, '
#  'suggesting that he was more effective in aerial duels compared to Dybala.\n'
#  '\n'
#  '**Overall Conclusion:**\n'
#  'In conclusion, both Paulo Dybala and Dusan Vlahovic had impressive seasons '
#  'in their respective years. Dybala excelled in creation, showcasing his '
#  "ability to create chances and influence the team's scoring probability. "
#  'Vlahovic, on the other hand, was a prolific goal-scorer with a strong '
#  "presence in aerial duels. In terms of overall performance, Dybala's "
#  'well-rounded contribution in creation, finishing, and dribbling skills make '
#  'him slightly better overall compared to Vlahovic in their respective '
#  'seasons.')

# %% [markdown]
# 10. Make all togheter in a single chain

# %%
def parse_player_info(extracted_dict)->list:
    return eval(extracted_dict.content)

def filter_and_format_data(extracted_dict: dict)->dict:
    players_to_filter = pd.DataFrame(extracted_dict)
    filtered_df = pd.merge(df, players_to_filter, on=['full_name', 'season'], how='inner')
    return filtered_df.to_dict(orient='records')

# %%
seasonal_report_chain = (RunnableMap(
            steps={
                    "input": lambda x: x['input'],
                    "data": (
                        player_info_template 
                        | llm 
                        | parse_player_info 
                        | filter_and_format_data
                    ),
                })
            | RunnableLambda(lambda x: x['steps'])
            | output_template
            | llm 
            )

# %%
res = seasonal_report_chain.invoke({'input': "Compare the seasonal performance of Cristiano Ronaldo and Romelu Lukaku in 2020"})
pprint(res.content)
# Out:
# ("**Analysis of Cristiano Ronaldo and Romelu Lukaku's Seasonal Performance in "
#  '2020**\n'
#  '\n'
#  '**Creation:**\n'
#  'When it comes to creating goal-scoring opportunities, Romelu Lukaku had a '
#  'standout season in 2020. He recorded 11 assists, showcasing his ability to '
#  'not only score goals but also set up his teammates effectively. His xA '
#  '(Expected Assists) value of 6.34 indicates that he was involved in creating '
#  'high-quality chances for his team. On the other hand, Cristiano Ronaldo, '
#  'while still contributing with 3 assists, had a lower xA value of 3.42. This '
#  'suggests that Lukaku was more efficient in creating goal-scoring '
#  'opportunities for his team compared to Ronaldo.\n'
#  '\n'
#  'In terms of expected threat (xT), both players had a similar impact on their '
#  "team's scoring probability. Lukaku's xT value of 3.02 and Ronaldo's xT value "
#  'of 3.81 indicate that they were both instrumental in moving the ball into '
#  'more threatening zones through their passes and carries. However, Ronaldo '
#  'had a higher xT from carries, showcasing his ability to drive the ball '
#  'forward effectively.\n'
#  '\n'
#  'When it comes to dribbling, Ronaldo had a higher success rate in winning '
#  "dribbles with a ratio of 0.61 compared to Lukaku's ratio of 0.57. This "
#  "indicates Ronaldo's superior dribbling skills and ability to beat defenders "
#  'in one-on-one situations.\n'
#  '\n'
#  '**Finishing:**\n'
#  'In terms of finishing, both players had impressive goal-scoring records in '
#  '2020. Ronaldo scored 29 goals with an xG (Expected Goals) value of 28.94, '
#  'indicating that he performed close to expectations in front of goal. Lukaku, '
#  'on the other hand, scored 24 goals with an xG value of 24.8, also performing '
#  'close to expectations.\n'
#  '\n'
#  'When it comes to aerial dominance, Ronaldo had a higher offensive AERO '
#  "rating of 72.28 compared to Lukaku's rating of 62.6. This suggests that "
#  'Ronaldo was more effective in winning offensive aerial duels against '
#  'opponents, showcasing his physical presence and ability to score goals from '
#  'headers.\n'
#  '\n'
#  '**Overall Conclusion:**\n'
#  'In conclusion, both Cristiano Ronaldo and Romelu Lukaku had impressive '
#  'seasonal performances in 2020. While Lukaku excelled in creating '
#  'goal-scoring opportunities for his team with his assists and xA value, '
#  'Ronaldo showcased his finishing prowess with a higher goal-scoring record '
#  'and superior aerial dominance. In a comparison between the two players, '
#  "Ronaldo's overall impact on the game, both in creating and finishing "
#  'chances, makes him the better performer in the 2020 season.')
